# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexanderG40/Data-Science/blob/main/Week9_Assignment_9_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load the dataset into a pandas dataframe and answer the following questions:

# %% [markdown]
# Describe the structure of the diabetes dataset (size,features, data types)

# %%
#Code here
#imported some of our data science librarys
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# here I loaded the diabetes dataframe
# we set up a delimeter to get rid of the \t
# https://www.scientecheasy.com/2022/09/delimiters-in-python.html/
df = pd.read_csv('/content/diabetes.txt', delimiter='\t')
# now we will get the shape of our dataframe
print(df.shape)
# Out:
# (442, 11)

# %%
df.columns
# Out:
# Index(['AGE', 'SEX', 'BMI', 'BP', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'Y'], dtype='object')

# %%
# we print our dtypes to get to know our dataset a bit more
df.dtypes
# Out:
# AGE      int64
# SEX      int64
# BMI    float64
# BP     float64
# S1       int64
# S2     float64
# S3     float64
# S4     float64
# S5     float64
# S6       int64
# Y        int64
# dtype: object

# %%
df.describe()
# Out:
#               AGE         SEX         BMI          BP          S1          S2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.375792   94.647014  189.140271  115.439140
# std     13.109028    0.499561    4.418122   13.831283   34.608052   30.413081
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   42.200000  133.000000  301.000000  242.400000
#
#                S3          S4          S5          S6           Y
# count  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    49.788462    4.070249    4.641411   91.260181  152.133484
# std     12.934202    1.290450    0.522391   11.496335   77.093005
# min     22.000000    2.000000    3.258100   58.000000   25.000000
# 25%     40.250000    3.000000    4.276700   83.250000   87.000000
# 50%     48.000000    4.000000    4.620050   91.000000  140.500000
# 75%     57.750000    5.000000    4.997200   98.000000  211.500000
# max     99.000000    9.090000    6.107000  124.000000  346.000000

# %% [markdown]
# Show the relationships between the target variable and the features using scatter plot and correlation analysis.

# %%
#Code here
# we will visualize the distribution of our target
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x = df["Y"])
plt.show()

# %%
# we will set up our scatterplot here
# this will be between BMI and Y because BMI normally means the persons body has to work harder
import numpy as np
sns.scatterplot(data = df, x = "BMI", y = "Y")
# Out:
# <Axes: xlabel='BMI', ylabel='Y'>

# %%
# our second scatterplot will be between AGE and the target
sns.scatterplot(data = df, x = "AGE", y = "Y")
# Out:
# <Axes: xlabel='AGE', ylabel='Y'>

# %% [markdown]
# Build a Simple Linear Regression Model (Single Feature):
#
# 1. Choose a single feature (body mass index) as the predictor variable and the s6 glu, blood sugar level as the target variable.
#
# 2. Split the dataset into training and testing sets.
#
# 3. Train a simple linear regression model using the training data.
#
# 4. Evaluate the model's accuracy using metrics such as mean squared error (MSE) or R-squared on both the training and testing sets.
#
# 5. Visualize the actual vs. predicted values of the target variable on the testing set.

# %%
# We start with number 1 using a scatterplot
sns.scatterplot(data = df, x = "BMI", y = "S6")
# Out:
# <Axes: xlabel='BMI', ylabel='S6'>

# %% [markdown]
# As we can see from this as the BMI went higher there is a correlation because the glucose level goes way up. Which means that their insulin has to be higher.

# %%
# we import our librarys needed
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# Build a Simple Linear Regression Model (Two Features):
#
# 1.Select two features (body mass index and age in years) as predictor variables and the s6 glu, blood sugar level as the target variable.
#
# 2.Split the dataset into training and testing sets.
# Train a simple linear regression model using the training data.
#
# 3.Assess the model's accuracy using metrics such as MSE or R-squared on both the training and testing sets.
#
# 4.Visualize the actual vs. predicted values of the target variable on the testing set.
